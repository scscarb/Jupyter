# %% [markdown]
# # Introduction to Jupyter Notebook
#
# This is a markdown cell. It lets me wrap text around my code and output.

# %%
# This is a code cell. Since this is a python notebook, I can write python code here, hit the play button above,
# and it will run that code. If my python code produces output, it will appear below the cell.
x = 2
y = 3
z = x + y
print(z)
# Out:
# 5

# %% [markdown]
# ## Jupyter for Cielo/HINTS tool
#
# The CIELO tool will serve two functions:
# 1. A searchable repository for the work the HSR team has done to replicate papers using the HINTS dataset.
# 2. An execution environment where researchers can run HSR team replications using their own HINTS related data.
#
# Jupyter Notebook is a possible platform for the second function.
#
# ### Using STATA in a Jupyter Notebook
# A user created package called *ipystata* allows the user to write and execute STATA code in a python notebook.

# %%
# import python STATA package
import ipystata
from ipystata.config import config_stata 
# the package is making calls to a locally installed version of STATA to run stata code. the config_stata function 
# tells the notebook where to find STATA.
config_stata('/Applications/Stata/StataMP.app/Contents/MacOS/StataMP')
# Out:
# IPyStata is loaded in batch mode.

# %% [markdown]
# With ipystata installed, I can now open a STATA session from the notebook using the call *%%stata*. Any code below this call in a code cell will be run in the STATA session. The STATA logfile and graphic output will appear as output in the notebook.

# %%
# %%stata -gr
# set obs 20
# gen x = runiform()
# gen y = runiform()
# mean x y
# scatter x y
# Out:
# number of observations (_N) was 0, now 20
#
# Mean estimation                   Number of obs   =         20
#
# --------------------------------------------------------------
#              |       Mean   Std. Err.     [95% Conf. Interval]
# -------------+------------------------------------------------
#            x |   .4687793   .0651381      .3324437    .6051148
#            y |   .5744606   .0701596      .4276149    .7213062
# --------------------------------------------------------------
#         <iframe
#             width="700"
#             height="400"
#             src="./temp_graph.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Limitations
# ### Limitations of ipystata
# - STATA can only be run in a Jupyter Notebook with a user created package. No support is available for this pakcage.
# - To run STATA, the notebook is making a call to a locally installed instance of STATA. We want users to be able to use STATA online.
# - Every time the Notebook sees %%stata, a new STATA session is opened. Any STATA process run in the previous code cell will be terminated. As a consequence, all code for a STATA session must be written in a single cell. This severely Jupyter Notebooks features.
#
# ### Limitations of Jupyter Notebooks
# - Hosting Jupyter Notebooks to be interactive online is possible, but the feasibility of doing so for this project is unknown.
# - can't run part of a code cell.

# %%
# %%stata
# local two  2
# display `red'
#
# global two 2
# display $red
#
# %%stata
# display `red'
# Out:
# red not found
# r(111);
#
# end of do-file
# r(111);

# %%
# %%stata
# mean x
# Out:
# no variables defined
# r(111);
#
# end of do-file
# r(111);

# %%
# %%stata
# display $red

# %% [markdown]
# ## Replication analysis

# %%
# %%stata
# cd "/Users/sethscarborough/Desktop/ HINTS/"
# use fullhintsdestring, replace
# rename *, lower
# //log using STATATemp/12,replace     // ACTIVATE LOG
#
# ****************************************************************************
# *** Phase 1: STANDARDIZE ALL THE VARIABLES
# *** The paper may use variables that don't exactly align to the way the data
# *** was collected. The first step is to ensure that variables are presented
# *** in the same manner as they were in the original paper
# ****************************************************************************
# *** These lines take existing variables (e.g. case genderc) to create new
# ***Variables (in this case sex).
# ***
# ***V0: Example - Sex
# ***    recode gendern (1=1 "Male") (2=2 "Female") (-9/0 = .), generate(sex)
# ***    replace sex = genderc if genderc != . // when gender is fixed, this line goes away
# ***    label variable sex "Sex"
# ***    tab sex datayr
# ***
# *** RECODE simultaneously recodes and creates a new variable, keeping the original variable intact.
# *** Note the recode has (-9/0 = .) which means from "-9 to 0, mark those as missing"
# ***
# *** REPLACE is used, when necessary, when the identical variabels are called different things.
# *** This is a workaround while we wait to repair the dataset and will be deleted eventually/
# ***
# *** LABEL is used to relabel the variable - otherwise it will show as RECODE of varname
# ***
# *** TAB is used as afinal tabulate is used to make sure that there are no other variable definitions out of range
# ****************************************************************************
# ***
# *** BASED ON Blake, Ottenbacher, Finney Rutten, Grady, Kobrin, Jacobson, and Hesse (2015)
# *** Paper Number: 12
# *** Using HINTS4c3
# ***
#
# ***V1: Sex
# recode genderc (1=1 "Male") (2=2 "Female") (-9/0 = .), generate(sex)
# label variable sex "Sex"
# tab sex datayr
#
# ***V2: Age Replication
# recode selfage (18/34=1 "18-34") (35/49=2 "35-49") (50/65=3 "50-64") (66/10000 = 4 ">65") (-9/0 = 0), gen (age3)
# tab age3 datayr
# 	***V2.1: Age Adjusted
# 	recode age (18/34=1 "18-34") (35/49=2 "35-49") (50/65=3 "50-64") (66/10000 = 4 ">65") (-9/0 = .), gen (age2)
# 	label variable age2 "Age"
# 	tab age2 datayr
#
# ***V3: Education
# recode educa (1=1 "Less than High School") (2=2 "12 years or completed High School") (3=3 "Technical, vocational, or some college") (4=4 "College Graduate or postgraduate") (nonmissing=.), generate(educ)
# label variable educ "Education"
# tab educ datayr
#
# ***V4: Race (Race_cat2 is not in HINTS 2 and 3, but other race variables should be able to be used. For this article, race_cat2 is definitely the variable used)
# generate racecattmp = hd09race1
# replace racecattmp=99 if hd09race1!=. & hd09race2!=.
# recode racecattmp (11=1 "White") (12=2 "Black") (13/15=3 "Other") (99=4 "Multiple races") (-9/0=.), gen(racecat)
# recode race_cat2 (11=1 "White") (12=2 "Black") (14 31/54=3 "Other") (16=4 "Multiple races") (-9/0=.), gen(race_cat3)
# replace racecat = race_cat3 if race_cat3!=.
# tab racecat datayr
#
# ***V5:Hispanic (nothisp is not in HINTS 2 and 3, but other race variables should be able to be used. For this article, nothisp is definitely the variable used)
# recode nothisp (-9=.) (1=1 "Not Hispanic") (2=2 "Hispanic"), gen (hisp)
# label variable hisp "Hispanic ethnicity"
# recode hispanic (1=2) (2=1) (-9/0 9=.)
# replace hisp = hispanic if hispanic!=.
# tab hisp datayr
#
# ***V6: Children in Household
# recode childreninhh (-9/-1 98=.) (0=0 "0") (1/30=1 ">=1"), gen (children)
# label variable children "Children under 18 in household"
# tab children datayr
#
# ***V7: Income
# recode incomeranges (-9/-1=.) (1/3=1 "0-$19,999") (4/5=2 "$20,000-$49,999") (6=3 "$50,000-$74,999") (7/9=4 ">=$75,000"), gen (income2)
# label variable income2 "Income"
# tab income2
#
# ***V8: Rurality
# recode ruc2003 (4/9 = 1 "Rural") (1/3=2 "Urban"), gen(metro)
# label variable metro "Metropolitan area"
# tab metro datayr
#
# ***V9: Health Insuance
# gen Healthinstmp=healthinsurance
# replace Healthinstmp=. if (datayr==2011|datayr==2013)&healthinsurance==2&(hccoverage_insurance!=2|hccoverage_private!=2|hccoverage_medicare!=2 ///
# |hccoverage_medicaid!=2|hccoverage_tricare!=2|hccoverage_va!=2|hccoverage_ihs!=2|hccoverage_other!=2)
# recode Healthinstmp (1=1 "yes")(2=2 "no")(-9/0 9=.), gen (Healthins)
# drop *tmp
# tab Healthins datayr
#
# ***V10: useinternet
# recode useinternet (-9/0 9=.) (1=2 "Yes") (2=1 "No"), gen(intuse)
# label variable intuse "Internet use"
# tab intuse datayr
#
# ***V11: heardhpv
# recode heardhpv (-9/0=.) (9=.) (1=2 "Yes") (2=1 "No"), gen(heard)
# label variable heard "Heard of HPV"
# tab heard datayr
# recode heard (1 = 0) (2 = 1),gen(heard01)
#
# ***V12: heardhpvvaccine
# recode heardhpvvaccine2 (-9/0=.) (9=.) (1=2 "Yes") (2=1 "No"), gen(heardvac)
# label variable heardvac "Heard of HPV vaccine"
# tab heardvac datayr
# recode heardvac (1 = 0) (2 = 1),gen(heardvac01)
#
# ***V13: hpvcausecancer_cervical
# recode hpvcausecancer_cervical (-9/0=.) (1=2 "Yes") (2=1 "No") (3=3 "Not sure"), gen(hpvcervical)
# label variable hpvcervical "HPV causes cancer"
# tab hpvcervical datayr
# recode hpvcervical (3=.), gen(hpvcervical2)
# recode hpvcervical (1 3= 0) (2 = 1),gen(hpvcervical01)
# *recode hpvcervical2 (1= 0) (2= 1),gen(hpvcervical02)
#
# ***V14: hpvstd
# recode hpvstd (-9/0=.) (1=2 "Yes") (2=1 "No") (3=3 "Not sure"), gen(std)
# label variable std "HPV is STD"
# tab std datayr
# recode std (3=.), gen(std2)
# recode std (1 3= 0) (2 = 1),gen(std01)
# *recode std2 (1= 0) (2 = 1),gen(std02)
#
# ***V15: hpvgoaway
# replace hpvgoaway = br70hpvgoawaymail if br70hpvgoawaymail!=.
# recode hpvgoaway (-9/0=.) (1=2 "Yes") (2=1 "No") (9 3=3 "Not sure"), gen(goaway)
# label variable goaway "HPV will go away on own"
# tab goaway datayr
# recode goaway (3=.), gen(goaway2)
# recode goaway (1 3= 0) (2 = 1),gen(goaway01)
# *recode goaway2 (1= 0) (2 = 1),gen(goaway02)
# ****************************************************************************
# *** Phase 2: SURVEY WEIGHTING DIAGNOSTIC (HINTS 2007 transition)
# *** NOTE: THIS CAN ONLY BE RUN IF THE VARIABLE WAS COLLECTED IN 2007
# ****************************************************************************
# *** In 2002 and 2005, data was collected using telephone surveys
# *** In 2007, data was collected using both telephone and mail surveys
# *** From 2010 to present, data is only collected using mail surveys
# ***
# *** To merge across the 2007 divide, we must determine if individuals respond to
# ***	the mail survey the same way they answered in questions on the phone?
# ***
# *** This is done in 3 steps according to Moser, et. al 2013
# ***
# *** PHASE 1, Step 1: Examine whether there are differences between phone and mail samples for HINTS 3
# ***
#
# gen evalwt = mwgt0 if sampflag == 1
#
# forvalues i = 1/50 {
# 	gen evalwgt`i' = mwgt`i' if sampflag==1
# }
#
# forvalues i = 51/100 {
# 	local j=`i' - 50
# 	gen evalwgt`i' = mwgt0 if sampflag==1
# }
#
#
# replace evalwt = rwgt0 if sampflag == 2
#
# forvalues i = 1/50 {
# 	replace evalwgt`i' = rwgt0 if sampflag==2
# }
#
# forvalues i = 51/100 {
# 	local j=`i' - 50
# 	replace evalwgt`i' = rwgt`j' if sampflag==2
# }
#
# svyset _n [pweight=evalwt], jkrweight(evalwgt*,multiplier(0.98)) vce(jackknife) mse
# ***   _n:  _n to indicate that individuals (instead of clusters) were randomly sampled
# ***   pweight = denote the inverse of the probability that the observation is included (use final)
#
# /*svy: tab sex sampflag, stubw(30)
# svy: tab age2 sampflag, stubw(30)
# svy: tab educ sampflag, stubw(30)
# svy: tab racecat sampflag, stubw(30)
# svy: tab hisp sampflag, stubw(30)
# svy: tab children sampflag, stubw(30)
# svy: tab income2 sampflag, stubw(30)
# svy: tab metro sampflag, stubw(30)
# svy: tab healthins sampflag, stubw(30)
# svy: tab intuse sampflag, stubw(30)
# svy: tab heard sampflag, stubw(30)
# svy: tab heardvac sampflag, stubw(30)
# svy: tab hpvcervical sampflag, stubw(30)
# svy: tab std sampflag, stubw(30)
# svy: tab goaway sampflag, stubw(30)
# * DEACTIVATE LOG AND CREATE PDF*/
#
# ********************************************************************************
# *** PHASE 1, Step 2: Evaluate the tables above to determine if there was a difference
# *** The GENERAL RULE is: If no differences at 0.01, then set HINTS 3 flag = 1
# *** otherwise set HINTS 3 flag = 2
# *** Bring tables to Dr. Huerta to evaluate
# ********************************************************************************
# *** 1 means that a composite is ok
# *** 2 means that you should use the phone data only
# *** 3 means that you should use the mail data only
# gen HINTS3_flag = 3 if datayr == 2007
# ********************************************************************************
# *** PHASE 3: PUT ALL THE CORRECT WEIGHTS INTO A SINGLE VARIABLE SET
# ***	2003 and 2005 use fwgt and fwgt*
# ***
# *** 2007 needs to replace fwgt & fwgt* with the appropriate sampling strategy
# *** based on the analysis above (HINTS3_flag)
# ***
# *** 2010 and on use person_finwt*
# ***
# *** This protocol standardizes on nfinalwt and nfwgt*
# ***
# *** Step 1: 2003 & 2005 recode. No need to
# ***
#
# gen nfinalwt = fwgt // 2003 and 2005 recode, blank in other years
#
# forvalues i = 1/50 {
# 	generate nfwgt`i' = fwgt`i'
# }
# tab datayr, summarize(nfinalwt)
# ***
# *** Step 2: 2007 recode.
# ***
#
# replace nfinalwt = cwgt0 if HINTS3_flag == 1 // 2007 recode - merged mail and phone
# replace nfinalwt = rwgt0 if HINTS3_flag == 2 // 2007 recode - phone only
# replace nfinalwt = mwgt0 if HINTS3_flag == 3 // 2007 recode - mail only
# tab datayr, summarize(nfinalwt)
#
# forvalues i = 1/50 {
# 	replace nfwgt`i' = cwgt`i' if HINTS3_flag == 1
# 	replace nfwgt`i' = rwgt`i' if HINTS3_flag == 2
# 	replace nfwgt`i' = mwgt`i' if HINTS3_flag == 3
# }
#
# ***
# *** Step 3: 2010 and beyond - recode
# ***
#
# replace nfinalwt = person_finwt0 if person_finwt0 != . // 2010 and forward recode
#
# forvalues i = 1/50 {
# 	replace nfwgt`i' = person_finwt`i' if person_finwt0 != .
# }
#
# tab datayr, summarize(nfinalwt)
# ********************************************************************************
# **  DROP DATAYRS THAT ARE OUT OF SCOPE - they are dropped if they DON'T have an
# **  asterisk - ANNOTATE WHY here THIS IS GENERALLY BASED ON PHASE 1
# **
# ** The var "seekcancerinfo" is only avialable in year 2003, 2012 and 2014
# **
# ** Most variables are only in HINTS 2,3 and 4c3
# **
# **
# ********************************************************************************
# ***
# *** The data year is dropped if there is NO ASTERISK
# ***
# ********************************************************************************
#
# drop if datayr == 2003 //heardvac heard children goaway std
# drop if datayr == 2005 //heardvac
# *drop if datayr == 2007
# drop if datayr == 2011 //heardvac heard goaway std
# drop if datayr == 2012 //heardvac heard goaway std
# *drop if datayr == 2013
# *drop if datayr == 2014 //goaway
# drop if sampflag!=1 & datayr==2007
# ********************************************************************************
# *** PHASE 4: CREATE A COMPOSITE WEIGHTING STRUCTURE ACROSS MULTIPLE YEARS
# *** Based on Moser et al 2013, Chapter 2, table 2-1
# ***
# *** Sets create a staggered weigthing set with 50 replicates per year
# *** e.g., when you use three years, you get 150 replicates
# *** All observations use their replicate weights when analyzing their year
# *** In all other years, they use their final replicate weight
# ***
#
# by datayr, sort: gen nvals = _n == 1
# gen nvals2 = sum(nvals)
# sum nvals
# return list
# local k = r(sum)
# display `k'
#
#
# forvalues j = 1/`k' {
# 	forvalues i = 1/50 {
# 		local l = (50 * `j') - 50 + `i'
# 		gen recfwgt`l' = nfinalwt
# 	}
# }
#
# forvalues j = 1/`k' {
# 	forvalues i = 1/50 {
# 		local l = (50 * `j') - 50 + `i'
# 	replace recfwgt`l' = nfwgt`i' if nvals2 == `j'
# 	}
# }
#
#
#
#
# ********************************************************************************
# svyset _n [pweight=nfinalwt], jkrweight(recfwgt*,multiplier(0.98)) vce(jackknife) mse
# ********************************************************************************
# ***  PHASE 5: CONDUCT THE ANALYSIS ACROSS YEARS
# ***  Table 1 - Replicate
# ********************************************************************************
# /*tab sex if datayr==2013
# tab age3 if datayr==2013
# tab educ if datayr==2013
# tab racecat if datayr==2013
# tab hisp if datayr==2013
# tab children if datayr==2013
# tab income2 if datayr==2013
# tab metro if datayr==2013
# tab healthins if datayr==2013
# tab intuse if datayr==2013
# svy: tab sex if datayr==2013, col
# svy: tab age3 if datayr==2013, col
# svy: tab educ if datayr==2013, col
# svy: tab racecat if datayr==2013, col
# svy: tab hisp if datayr==2013, col
# svy: tab children if datayr==2013, col
# svy: tab income2 if datayr==2013, col
# svy: tab metro if datayr==2013, col
# svy: tab healthins if datayr==2013, col
# svy: tab intuse if datayr==2013, col*/
# ********************************************************************************
# ***  Table 1 - Adjust/Extend
# ********************************************************************************
# tab sex datayr
# tab age2 datayr
# tab educ datayr
# tab racecat datayr
# tab hisp datayr
# tab children datayr
# tab income2 datayr
# tab metro datayr
# tab Healthins datayr
# tab intuse datayr
# svy: tab sex datayr, col
# svy: tab age2 datayr, col
# svy: tab educ datayr, col
# svy: tab racecat datayr, col
# svy: tab hisp datayr, col
# svy: tab children datayr, col
# svy: tab income2 datayr, col
# svy: tab metro datayr, col
# svy: tab Healthins datayr, col
# svy: tab intuse datayr, col
#
# log close
# *translate STATATemp/12.smcl STATAResults/12.pdf, replace
# Out:
# /Users/sethscarborough/Desktop/ HINTS
# . ****************************************************************************. *** The paper may use variables that don't exactly align to the way the data. *** in the same manner as they were in the original paper. *** These lines take existing variables (e.g. case genderc) to create new. ***. ***    recode gendern (1=1 "Male") (2=2 "Female") (-9/0 = .), generate(sex). ***    label variable sex "Sex". ***. *** Note the recode has (-9/0 = .) which means from "-9 to 0, mark those as missing". *** REPLACE is used, when necessary, when the identical variabels are called different things.. ***. *** . ****************************************************************************. *** BASED ON Blake, Ottenbacher, Finney Rutten, Grady, Kobrin, Jacobson, and Hesse (2015). *** Using HINTS4c3. ***V1: Sex(322 differences between genderc and sex)
#
#            |                                    datayr
#        Sex |      2003       2005       2007       2011       2012       2013       2014 |     Total
# -----------+-----------------------------------------------------------------------------+----------
#       Male |     2,521      1,929      2,969      1,552      1,390      1,197      1,424 |    12,982
#     Female |     3,848      3,657      4,696      2,304      2,172      1,906      2,184 |    20,767
# -----------+-----------------------------------------------------------------------------+----------
#      Total |     6,369      5,586      7,665      3,856      3,562      3,103      3,608 |    33,749
#
# . recode selfage (18/34=1 "18-34") (35/49=2 "35-49") (50/65=3 "50-64") (66/10000 = 4 ">65") (-9/0 = 0), gen (age3)
# (10492 differences between selfage and age3)
#
#  RECODE of |
#    selfage |
#      (N13. |
#      Self: |              datayr
#      Age.) |      2012       2013       2014 |     Total
# -----------+---------------------------------+----------
#          0 |       233        304        306 |       843
#      18-34 |       524        413        467 |     1,404
#      35-49 |       816        671        731 |     2,218
#      50-64 |     1,226      1,064      1,273 |     3,563
#        >65 |       831        733        900 |     2,464
# -----------+---------------------------------+----------
#      Total |     3,630      3,185      3,677 |    10,492
#
# .         recode age (18/34=1 "18-34") (35/49=2 "35-49") (50/65=3 "50-64") (66/10000 = 4 ">65") (-9/0 = .), gen (age2)
# (34024 differences between age and age2)
#
#            |                                    datayr
#        Age |      2003       2005       2007       2011       2012       2013       2014 |     Total
# -----------+-----------------------------------------------------------------------------+----------
#      18-34 |     1,655      1,037      1,113        582        529        426        467 |     5,809
#      35-49 |     1,954      1,490      1,830        932        845        712        743 |     8,506
#      50-64 |     1,579      1,619      2,633      1,419      1,264      1,136      1,323 |    10,973
#        >65 |     1,155      1,422      2,017        958        873        808        962 |     8,195
# -----------+-----------------------------------------------------------------------------+----------
#      Total |     6,343      5,568      7,593      3,891      3,511      3,082      3,495 |    33,483
#
# . ***V3: Education> educ)
# (456 differences between educa and educ)
#
#                       |                                    datayr
#             Education |      2003       2005       2007       2011       2012       2013       2014 |     Total
# ----------------------+-----------------------------------------------------------------------------+----------
# Less than High School |       747        687        683        391        329        297        308 |     3,442
# 12 years or completed |     1,828      1,447      1,804        785        775        699        670 |     8,008
# Technical, vocational |     1,637      1,545      2,192      1,167      1,057        933      1,090 |     9,621
# College Graduate or p |     1,927      1,696      2,637      1,531      1,380      1,167      1,458 |    11,796
# ----------------------+-----------------------------------------------------------------------------+----------
#                 Total |     6,139      5,375      7,316      3,874      3,541      3,096      3,526 |    32,867
#
# . generate racecattmp = hd09race1
# (15,361 missing values generated)
# (406 real changes made)
# (18719 differences between racecattmp and racecat)
# (10492 differences between race_cat2 and race_cat3)
# (9,645 real changes made)
#
#      RECODE of |                              datayr
#     racecattmp |      2003       2005       2007       2012       2013       2014 |     Total
# ---------------+------------------------------------------------------------------+----------
#          White |     4,632      4,378      5,803      2,519      2,078      2,408 |    21,818
#          Black |       740        462        718        614        546        626 |     3,706
#          Other |       294        229        349        159        163        189 |     1,383
# Multiple races |       134        110        162        111        104        128 |       749
# ---------------+------------------------------------------------------------------+----------
#          Total |     5,800      5,179      7,032      3,403      2,891      3,351 |    27,656
#
# . recode nothisp (-9=.) (1=1 "Not Hispanic") (2=2 "Hispanic"), gen (hisp)
# (1098 differences between nothisp and hisp)
# (hispanic: 22763 changes made)
# (22,495 real changes made)
#
#     Hispanic |                                    datayr
#    ethnicity |      2003       2005       2007       2011       2012       2013       2014 |     Total
# -------------+-----------------------------------------------------------------------------+----------
# Not Hispanic |     5,346      4,874      6,610      3,322      2,768      2,301      2,769 |    27,990
#     Hispanic |       764        496        622        461        511        511        534 |     3,899
# -------------+-----------------------------------------------------------------------------+----------
#        Total |     6,110      5,370      7,232      3,783      3,279      2,812      3,303 |    31,889
#
# . recode childreninhh (-9/-1 98=.) (0=0 "0") (1/30=1 ">=1"), gen (children)
# (5932 differences between childreninhh and children)
#
#   Children |
#   under 18 |
#         in |                              datayr
#  household |      2005       2007       2011       2012       2013       2014 |     Total
# -----------+------------------------------------------------------------------+----------
#          0 |     1,988      5,187      2,548      2,282      1,884      2,352 |    16,241
#        >=1 |     1,714      2,101      1,074        977        811        923 |     7,600
# -----------+------------------------------------------------------------------+----------
#      Total |     3,702      7,288      3,622      3,259      2,695      3,275 |    23,841
#
# . recode incomeranges (-9/-1=.) (1/3=1 "0-$19,999") (4/5=2 "$20,000-$49,999") (6=3 "$50,000-$74,999") (7/9=4 ">=$75,000"), gen (income2)
# (19871 differences between incomeranges and income2)
#
#          Income |      Freq.     Percent        Cum.
# ----------------+-----------------------------------
#       0-$19,999 |      4,165       21.88       21.88
# $20,000-$49,999 |      5,776       30.34       52.22
# $50,000-$74,999 |      3,317       17.42       69.65
#       >=$75,000 |      5,778       30.35      100.00
# ----------------+-----------------------------------
#           Total |     19,036      100.00
# . recode ruc2003 (4/9 = 1 "Rural") (1/3=2 "Urban"), gen(metro)
# (27182 differences between ruc2003 and metro)
#
# Metropolit |                                    datayr
#    an area |      2003       2005       2007       2011       2012       2013       2014 |     Total
# -----------+-----------------------------------------------------------------------------+----------
#      Rural |     1,195      1,234      1,482        638        543        476        520 |     6,088
#      Urban |     5,174      4,352      6,192      3,321      3,087      2,709      3,157 |    27,992
# -----------+-----------------------------------------------------------------------------+----------
#      Total |     6,369      5,586      7,674      3,959      3,630      3,185      3,677 |    34,080
#
# . gen Healthinstmp=healthinsurance
# (516 missing values generated)
# > |hccoverage_medicaid!=2|hccoverage_tricare!=2|hccoverage_va!=2|hccoverage_ihs!=2|hccoverage_other!=2)
# (65 real changes made, 65 to missing)
# (236 differences between Healthinstmp and Healthins)
#
#  RECODE of |
# Healthinst |                                    datayr
#         mp |      2003       2005       2007       2011       2012       2013       2014 |     Total
# -----------+-----------------------------------------------------------------------------+----------
#        yes |     5,357      4,749      6,666      3,548      2,999      2,782      3,183 |    29,284
#         no |       777        639        878        345        584        324        432 |     3,979
# -----------+-----------------------------------------------------------------------------+----------
#      Total |     6,134      5,388      7,544      3,893      3,583      3,106      3,615 |    33,263
#
# . recode useinternet (-9/0 9=.) (1=2 "Yes") (2=1 "No"), gen(intuse)
# (34057 differences between useinternet and intuse)
#
#   Internet |                                    datayr
#        use |      2003       2005       2007       2011       2012       2013       2014 |     Total
# -----------+-----------------------------------------------------------------------------+----------
#         No |     2,376      2,336      2,566      1,043        909        880        827 |    10,937
#        Yes |     3,982      3,244      5,078      2,914      2,720      2,284      2,802 |    23,024
# -----------+-----------------------------------------------------------------------------+----------
#      Total |     6,358      5,580      7,644      3,957      3,629      3,164      3,629 |    33,961
#
# . recode heardhpv (-9/0=.) (9=.) (1=2 "Yes") (2=1 "No"), gen(heard)
# (17798 differences between heardhpv and heard)
#
#   Heard of |                   datayr
#        HPV |      2005       2007       2013       2014 |     Total
# -----------+--------------------------------------------+----------
#         No |     2,202      2,435      1,097      1,389 |     7,123
#        Yes |     1,336      4,912      2,009      2,239 |    10,496
# -----------+--------------------------------------------+----------
#      Total |     3,538      7,347      3,106      3,628 |    17,619
#
# (17619 differences between heard and heard01)
# . recode heardhpvvaccine2 (-9/0=.) (9=.) (1=2 "Yes") (2=1 "No"), gen(heardvac)
# (14214 differences between heardhpvvaccine2 and heardvac)
#
#   Heard of |
#        HPV |              datayr
#    vaccine |      2007       2013       2014 |     Total
# -----------+---------------------------------+----------
#         No |     2,296      1,048      1,408 |     4,752
#        Yes |     5,025      2,022      2,182 |     9,229
# -----------+---------------------------------+----------
#      Total |     7,321      3,070      3,590 |    13,981
#
# (13981 differences between heardvac and heardvac01)
# . recode hpvcausecancer_cervical (-9/0=.) (1=2 "Yes") (2=1 "No") (3=3 "Not sure"), gen(hpvcervical)
# (11701 differences between hpvcausecancer_cervical and hpvcervical)
#
# HPV causes |                   datayr
#     cancer |      2005       2007       2013       2014 |     Total
# -----------+--------------------------------------------+----------
#         No |       117        360         99         35 |       611
#        Yes |       624      3,544      1,149      1,649 |     6,966
#   Not sure |         0          0        723        510 |     1,233
# -----------+--------------------------------------------+----------
#      Total |       741      3,904      1,971      2,194 |     8,810
#
# (1233 differences between hpvcervical and hpvcervical2)
# (8810 differences between hpvcervical and hpvcervical01)
# . ***V14: hpvstd(11991 differences between hpvstd and std)
#
#            |                   datayr
# HPV is STD |      2005       2007       2013       2014 |     Total
# -----------+--------------------------------------------+----------
#         No |       128        826        402        300 |     1,656
#        Yes |       855      3,245      1,075      1,452 |     6,627
#   Not sure |         0          0        495        455 |       950
# -----------+--------------------------------------------+----------
#      Total |       983      4,071      1,972      2,207 |     9,233
#
# (950 differences between std and std2)
# (9233 differences between std and std01)
# . ***V15: hpvgoaway(2,166 real changes made)
# (7897 differences between hpvgoaway and goaway)
#
#   HPV will |
# go away on |              datayr
#        own |      2005       2007       2013 |     Total
# -----------+---------------------------------+----------
#         No |     1,072      3,365      1,288 |     5,725
#        Yes |        44        299         92 |       435
#   Not sure |         0          0        587 |       587
# -----------+---------------------------------+----------
#      Total |     1,116      3,664      1,967 |     6,747
#
# (587 differences between goaway and goaway2)
# (6747 differences between goaway and goaway01)
# . ****************************************************************************. *** NOTE: THIS CAN ONLY BE RUN IF THE VARIABLE WAS COLLECTED IN 2007. *** In 2002 and 2005, data was collected using telephone surveys. *** From 2010 to present, data is only collected using mail surveys. *** To merge across the 2007 divide, we must determine if individuals respond to. *** . ***. ***(30,487 missing values generated)(30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)(30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (30,487 missing values generated)
# (4,081 real changes made)(4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)(4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
# (4,081 real changes made)
#
#       pweight: evalwt
#           VCE: jackknife
#           MSE: on
#     jkrweight: evalwgt1 evalwgt2 evalwgt3 evalwgt4 evalwgt5 evalwgt6 evalwgt7 evalwgt8 evalwgt9 evalwgt10 evalwgt11 evalwgt12 evalwgt13 evalwgt14 evalwgt15 evalwgt16 evalwgt17 evalwgt18 evalwgt19
#                evalwgt20 evalwgt21 evalwgt22 evalwgt23 evalwgt24 evalwgt25 evalwgt26 evalwgt27 evalwgt28 evalwgt29 evalwgt30 evalwgt31 evalwgt32 evalwgt33 evalwgt34 evalwgt35 evalwgt36 evalwgt37
#                evalwgt38 evalwgt39 evalwgt40 evalwgt41 evalwgt42 evalwgt43 evalwgt44 evalwgt45 evalwgt46 evalwgt47 evalwgt48 evalwgt49 evalwgt50 evalwgt51 evalwgt52 evalwgt53 evalwgt54 evalwgt55
#                evalwgt56 evalwgt57 evalwgt58 evalwgt59 evalwgt60 evalwgt61 evalwgt62 evalwgt63 evalwgt64 evalwgt65 evalwgt66 evalwgt67 evalwgt68 evalwgt69 evalwgt70 evalwgt71 evalwgt72 evalwgt73
#                evalwgt74 evalwgt75 evalwgt76 evalwgt77 evalwgt78 evalwgt79 evalwgt80 evalwgt81 evalwgt82 evalwgt83 evalwgt84 evalwgt85 evalwgt86 evalwgt87 evalwgt88 evalwgt89 evalwgt90 evalwgt91
#                evalwgt92 evalwgt93 evalwgt94 evalwgt95 evalwgt96 evalwgt97 evalwgt98 evalwgt99 evalwgt100
#   Single unit: missing
#      Strata 1: <one>
#          SU 1: <observations>
#         FPC 1: <zero>
# . ***   pweight = denote the inverse of the probability that the observation is included (use final)> svy: tab age2 sampflag, stubw(30)
# > svy: tab educ sampflag, stubw(30)
# > svy: tab racecat sampflag, stubw(30)
# > svy: tab hisp sampflag, stubw(30)
# > svy: tab children sampflag, stubw(30)
# > svy: tab income2 sampflag, stubw(30)
# > svy: tab metro sampflag, stubw(30)
# > svy: tab healthins sampflag, stubw(30)
# > svy: tab intuse sampflag, stubw(30)
# > svy: tab heard sampflag, stubw(30)
# > svy: tab heardvac sampflag, stubw(30)
# > svy: tab hpvcervical sampflag, stubw(30)
# > svy: tab std sampflag, stubw(30)
# > svy: tab goaway sampflag, stubw(30)
# > * DEACTIVATE LOG AND CREATE PDF*/. *** PHASE 1, Step 2: Evaluate the tables above to determine if there was a difference. *** otherwise set HINTS 3 flag =(26,406 missing values generated)
# . *** PHASE 3: PUT ALL THE CORRECT WEIGHTS INTO A SINGLE VARIABLE SET. ***. *** based on the analysis above (HINTS3_flag). *** 2010 and on use person_finwt*. *** This protocol standardizes on nfinalwt and nfwgt*. *** Step 1: 2003 & 2005 recode. No need to . gen nfinalwt = fwgt // 2003 and 2005 recode, blank in other years
# (22,125 missing values generated)
# . forvalues i = 1/50 {(22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
# (22,125 missing values generated)
#
#             |         Summary of nfinalwt
#      datayr |        Mean   Std. Dev.       Freq.
# ------------+------------------------------------
#        2003 |   32886.543   23292.173       6,369
#        2005 |   38765.981   40188.195       5,586
# ------------+------------------------------------
#       Total |   35633.723   32437.577      11,955
# . *** Step 2: 2007 recode.. replace nfinalwt = cwgt0 if HINTS3_flag == 1 // 2007 recode - merged mail and phone
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
#
#             |         Summary of nfinalwt
#      datayr |        Mean   Std. Dev.       Freq.
# ------------+------------------------------------
#        2003 |   32886.543   23292.173       6,369
#        2005 |   38765.981   40188.195       5,586
#        2007 |   62792.476   60093.565       3,593
# ------------+------------------------------------
#       Total |   41909.862   42124.143      15,548(0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# (0 real changes made)
# (0 real changes made)
# (3,593 real changes made)
# . *** Step 3: 2010 and beyond - recode. replace nfinalwt = person_finwt0 if person_finwt0 != . // 2010 and forward recode
# (14,451 real changes made)(14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
# (14,451 real changes made)
#
#             |         Summary of nfinalwt
#      datayr |        Mean   Std. Dev.       Freq.
# ------------+------------------------------------
#        2003 |   32886.543   23292.173       6,369
#        2005 |   38765.981   40188.195       5,586
#        2007 |   62792.476   60093.565       3,593
#        2011 |   59413.317   78556.868       3,959
#        2012 |    65476.92   86412.132       3,630
#        2013 |   73833.235   95604.856       3,185
#        2014 |   64633.972   85722.939       3,677
# ------------+------------------------------------
#       Total |   53246.143   68252.956      29,999
# . **  DROP DATAYRS THAT ARE OUT OF SCOPE - they are dropped if they DON'T have an. ** . **. **. ********************************************************************************. *** The data year is dropped if there is NO ASTERISK. ********************************************************************************(6,369 observations deleted)
# (5,586 observations deleted)
# . drop if datayr == 2011 //heardvac heard goaway std
# (3,959 observations deleted)
# (3,630 observations deleted)
# . *drop if datayr == 2014 //goaway(4,081 observations deleted)
# . *** PHASE 4: CREATE A COMPOSITE WEIGHTING STRUCTURE ACROSS MULTIPLE YEARS. ***. *** e.g., when you use three years, you get 150 replicates. *** In all other years, they use their final replicate weight. by datayr, sort: gen nvals = _n == 1
#
#     Variable |        Obs        Mean    Std. Dev.       Min        Max
# -------------+---------------------------------------------------------
#        nvals |     10,455    .0002869    .0169378          0          1
#
# scalars:
#                   r(N) =  10455
#               r(sum_w) =  10455
#                r(mean) =  .000286944045911
#                 r(Var) =  .0002868891494033
#                  r(sd) =  .0169378023782106
#                 r(min) =  0
#                 r(max) =  1
#                 r(sum) =  3
# 3(3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,593 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,185 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
# (3,677 real changes made)
#
# . . svyset _n [pweight=nfinalwt], jkrweight(recfwgt*,multiplier(0.98)) vce(jackknife) mse
#
#       pweight: nfinalwt
#           VCE: jackknife
#           MSE: on
#     jkrweight: recfwgt1 recfwgt2 recfwgt3 recfwgt4 recfwgt5 recfwgt6 recfwgt7 recfwgt8 recfwgt9 recfwgt10 recfwgt11 recfwgt12 recfwgt13 recfwgt14 recfwgt15 recfwgt16 recfwgt17 recfwgt18 recfwgt19
#                recfwgt20 recfwgt21 recfwgt22 recfwgt23 recfwgt24 recfwgt25 recfwgt26 recfwgt27 recfwgt28 recfwgt29 recfwgt30 recfwgt31 recfwgt32 recfwgt33 recfwgt34 recfwgt35 recfwgt36 recfwgt37
#                recfwgt38 recfwgt39 recfwgt40 recfwgt41 recfwgt42 recfwgt43 recfwgt44 recfwgt45 recfwgt46 recfwgt47 recfwgt48 recfwgt49 recfwgt50 recfwgt51 recfwgt52 recfwgt53 recfwgt54 recfwgt55
#                recfwgt56 recfwgt57 recfwgt58 recfwgt59 recfwgt60 recfwgt61 recfwgt62 recfwgt63 recfwgt64 recfwgt65 recfwgt66 recfwgt67 recfwgt68 recfwgt69 recfwgt70 recfwgt71 recfwgt72 recfwgt73
#                recfwgt74 recfwgt75 recfwgt76 recfwgt77 recfwgt78 recfwgt79 recfwgt80 recfwgt81 recfwgt82 recfwgt83 recfwgt84 recfwgt85 recfwgt86 recfwgt87 recfwgt88 recfwgt89 recfwgt90 recfwgt91
#                recfwgt92 recfwgt93 recfwgt94 recfwgt95 recfwgt96 recfwgt97 recfwgt98 recfwgt99 recfwgt100 recfwgt101 recfwgt102 recfwgt103 recfwgt104 recfwgt105 recfwgt106 recfwgt107 recfwgt108
#                recfwgt109 recfwgt110 recfwgt111 recfwgt112 recfwgt113 recfwgt114 recfwgt115 recfwgt116 recfwgt117 recfwgt118 recfwgt119 recfwgt120 recfwgt121 recfwgt122 recfwgt123 recfwgt124
#                recfwgt125 recfwgt126 recfwgt127 recfwgt128 recfwgt129 recfwgt130 recfwgt131 recfwgt132 recfwgt133 recfwgt134 recfwgt135 recfwgt136 recfwgt137 recfwgt138 recfwgt139 recfwgt140
#                recfwgt141 recfwgt142 recfwgt143 recfwgt144 recfwgt145 recfwgt146 recfwgt147 recfwgt148 recfwgt149 recfwgt150
#   Single unit: missing
#      Strata 1: <one>
#          SU 1: <observations>
#         FPC 1: <zero>
# . ***  PHASE 5: CONDUCT THE ANALYSIS ACROSS YEARS. ********************************************************************************> tab age3 if datayr==2013
# > tab educ if datayr==2013
# > tab racecat if datayr==2013
# > tab hisp if datayr==2013
# > tab children if datayr==2013
# > tab income2 if datayr==2013
# > tab metro if datayr==2013
# > tab healthins if datayr==2013
# > tab intuse if datayr==2013
# > svy: tab sex if datayr==2013, col
# > svy: tab age3 if datayr==2013, col
# > svy: tab educ if datayr==2013, col
# > svy: tab racecat if datayr==2013, col
# > svy: tab hisp if datayr==2013, col
# > svy: tab children if datayr==2013, col
# > svy: tab income2 if datayr==2013, col
# > svy: tab metro if datayr==2013, col
# > svy: tab healthins if datayr==2013, col
# > svy: tab intuse if datayr==2013, col*/. ***  Table 1 - Adjust/Extend. tab sex datayr
#
#            |              datayr
#        Sex |      2007       2013       2014 |     Total
# -----------+---------------------------------+----------
#       Male |     1,385      1,197      1,424 |     4,006
#     Female |     2,199      1,906      2,184 |     6,289
# -----------+---------------------------------+----------
#      Total |     3,584      3,103      3,608 |    10,295
#
#
#            |              datayr
#        Age |      2007       2013       2014 |     Total
# -----------+---------------------------------+----------
#      18-34 |       621        426        467 |     1,514
#      35-49 |       904        712        743 |     2,359
#      50-64 |     1,246      1,136      1,323 |     3,705
#        >65 |       766        808        962 |     2,536
# -----------+---------------------------------+----------
#      Total |     3,537      3,082      3,495 |    10,114
#
#
#                       |              datayr
#             Education |      2007       2013       2014 |     Total
# ----------------------+---------------------------------+----------
# Less than High School |       316        297        308 |       921
# 12 years or completed |       819        699        670 |     2,188
# Technical, vocational |     1,145        933      1,090 |     3,168
# College Graduate or p |     1,280      1,167      1,458 |     3,905
# ----------------------+---------------------------------+----------
#                 Total |     3,560      3,096      3,526 |    10,182
#
#
#      RECODE of |              datayr
#     racecattmp |      2007       2013       2014 |     Total
# ---------------+---------------------------------+----------
#          White |     2,672      2,078      2,408 |     7,158
#          Black |       463        546        626 |     1,635
#          Other |       194        163        189 |       546
# Multiple races |        77        104        128 |       309
# ---------------+---------------------------------+----------
#          Total |     3,406      2,891      3,351 |     9,648
#
#
#     Hispanic |              datayr
#    ethnicity |      2007       2013       2014 |     Total
# -------------+---------------------------------+----------
# Not Hispanic |     3,166      2,301      2,769 |     8,236
#     Hispanic |       324        511        534 |     1,369
# -------------+---------------------------------+----------
#        Total |     3,490      2,812      3,303 |     9,605
#
#
#   Children |
#   under 18 |
#         in |              datayr
#  household |      2007       2013       2014 |     Total
# -----------+---------------------------------+----------
#          0 |     2,461      1,884      2,352 |     6,697
#        >=1 |     1,070        811        923 |     2,804
# -----------+---------------------------------+----------
#      Total |     3,531      2,695      3,275 |     9,501
#
#
#                 |              datayr
#          Income |      2007       2013       2014 |     Total
# ----------------+---------------------------------+----------
#       0-$19,999 |       616        680        774 |     2,070
# $20,000-$49,999 |       959        812        971 |     2,742
# $50,000-$74,999 |       618        446        550 |     1,614
#       >=$75,000 |     1,029        801        979 |     2,809
# ----------------+---------------------------------+----------
#           Total |     3,222      2,739      3,274 |     9,235
#
#
# Metropolit |              datayr
#    an area |      2007       2013       2014 |     Total
# -----------+---------------------------------+----------
#      Rural |       616        476        520 |     1,612
#      Urban |     2,977      2,709      3,157 |     8,843
# -----------+---------------------------------+----------
#      Total |     3,593      3,185      3,677 |    10,455
#
#
#  RECODE of |
# Healthinst |              datayr
#         mp |      2007       2013       2014 |     Total
# -----------+---------------------------------+----------
#        yes |     3,067      2,782      3,183 |     9,032
#         no |       433        324        432 |     1,189
# -----------+---------------------------------+----------
#      Total |     3,500      3,106      3,615 |    10,221
#
#
#   Internet |              datayr
#        use |      2007       2013       2014 |     Total
# -----------+---------------------------------+----------
#         No |     1,042        880        827 |     2,749
#        Yes |     2,528      2,284      2,802 |     7,614
# -----------+---------------------------------+----------
#      Total |     3,570      3,164      3,629 |    10,363
#
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =       10,295
#                                               Population size   =  688,682,788
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
#           |           datayr
#       Sex |  2007   2013   2014  Total
# ----------+---------------------------
#      Male | .4852  .4839  .4826  .4839
#    Female | .5148  .5161  .5174  .5161
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(2)         =    0.0466
#     Design-based  F(1.98, 295.64) =    0.6579     P = 0.5175
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =       10,114
#                                               Population size   =  679,114,279
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
#           |           datayr
#       Age |  2007   2013   2014  Total
# ----------+---------------------------
#     18-34 | .3051  .2716  .3076  .2947
#     35-49 | .2973  .3046  .2668  .2895
#     50-64 |  .245  .2639  .2654  .2582
#       >65 | .1527  .1599  .1602  .1576
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(6)         =   22.8381
#     Design-based  F(2.09, 311.21) =   16.5368     P = 0.0000
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =       10,182
#                                               Population size   =  683,731,334
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
#           |           datayr
# Education |  2007   2013   2014  Total
# ----------+---------------------------
#  Less tha | .1402  .0967  .1163  .1175
#  12 years | .2448  .2445  .1819  .2235
#  Technica |  .368  .3268  .3003  .3313
#   College | .2469  .3321  .4015  .3277
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(6)         =  214.2148
#     Design-based  F(3.94, 587.04) =   40.1178     P = 0.0000
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =        9,648
#                                               Population size   =  645,504,336
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
# RECODE of |
# racecattm |           datayr
# p         |  2007   2013   2014  Total
# ----------+---------------------------
#     White | .7874   .783  .7794  .7832
#     Black |  .126  .1289  .1298  .1283
#     Other | .0669  .0657  .0679  .0668
#  Multiple | .0198  .0224   .023  .0217
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(6)         =    1.3094
#     Design-based  F(4.40, 654.93) =    0.4121     P = 0.8175
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =        9,605
#                                               Population size   =  652,169,969
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
# Hispanic  |           datayr
# ethnicity |  2007   2013   2014  Total
# ----------+---------------------------
#  Not Hisp | .8689  .8502  .8505  .8566
#  Hispanic | .1311  .1498  .1495  .1434
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(2)         =    6.0170
#     Design-based  F(1.72, 256.24) =   39.0473     P = 0.0000
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =        9,501
#                                               Population size   =  648,322,335
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
# Children  |
# under 18  |
# in        |           datayr
# household |  2007   2013   2014  Total
# ----------+---------------------------
#         0 | .6255  .6196  .6404  .6286
#       >=1 | .3745  .3804  .3596  .3714
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(2)         =    3.0974
#     Design-based  F(1.95, 290.52) =    0.8226     P = 0.4376
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =        9,235
#                                               Population size   =  625,808,690
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
#           |           datayr
#    Income |  2007   2013   2014  Total
# ----------+---------------------------
#  0-$19,99 | .2114  .2015  .1938  .2021
#  $20,000- | .3027  .2919  .2753  .2897
#  $50,000- | .1792  .1769  .1725  .1761
#  >=$75,00 | .3068  .3297  .3585  .3321
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(6)         =   19.3574
#     Design-based  F(5.50, 818.87) =    1.3775     P = 0.2256
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =       10,455
#                                               Population size   =  698,431,335
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
# Metropoli |           datayr
# tan area  |  2007   2013   2014  Total
# ----------+---------------------------
#     Rural | .1644   .179  .1639  .1691
#     Urban | .8356   .821  .8361  .8309
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(2)         =    3.6712
#     Design-based  F(1.88, 280.15) =    0.7551     P = 0.4634
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =       10,221
#                                               Population size   =  686,158,760
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
# RECODE of |
# Healthins |           datayr
# tmp       |  2007   2013   2014  Total
# ----------+---------------------------
#       yes | .8247  .8378  .8732  .8457
#        no | .1753  .1622  .1268  .1543
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(2)         =   32.9899
#     Design-based  F(1.59, 236.48) =  162.3934     P = 0.0000
# (running tabulate on estimation sample)
#
# Number of strata   =         1                Number of obs     =       10,363
#                                               Population size   =  694,648,677
#                                               Replications      =          150
#                                               Design df         =          149
#
# --------------------------------------
# Internet  |           datayr
# use       |  2007   2013   2014  Total
# ----------+---------------------------
#        No | .2887   .217  .1659  .2228
#       Yes | .7113   .783  .8341  .7772
#           |
#     Total |     1      1      1      1
# --------------------------------------
#   Key:  column proportion
#
#   Pearson:
#     Uncorrected   chi2(2)         =  150.4808
#     Design-based  F(1.94, 289.28) =   55.1636     P = 0.0000
